# %%
import pandas as pd

input_file = r"C:\Users\shenbagam\Downloads\FINALPROJECT\DataSet\fact_transactions.csv"

output_file = r"C:\Users\shenbagam\Downloads\FINALPROJECT\revenue\customer_revenue_data.csv"

df = pd.read_csv(input_file)

selected_df = df[["Customer_ID", "Fiscal_Quarter", "Transaction_Amount_Local", "FX_Rate_To_USD", "Discount_Pct"]]

selected_df.to_csv(output_file, index=False)

print(f"✅ Saved selected columns to {output_file} with shape {selected_df.shape}")
# Out:
# ✅ Saved selected columns to C:\Users\shenbagam\Downloads\FINALPROJECT\revenue\customer_revenue_data.csv with shape (54858, 5)

# %%
import os
import pandas as pd

input_file = r"C:\Users\shenbagam\Downloads\FINALPROJECT\revenue\customer_revenue_data.csv"
output_folder = r"C:\Users\shenbagam\Downloads\FINALPROJECT\revenue\cleaned"
os.makedirs(output_folder, exist_ok=True)

output_file = os.path.join(output_folder, "customer_revenue_data_cleaned.csv")
df = pd.read_csv(input_file)

df.columns = df.columns.str.strip().str.replace(" ", "_")

if "Customer_ID" in df.columns:
    df["Customer_ID"] = pd.to_numeric(df["Customer_ID"], errors="coerce").astype("Int64")

if "Fiscal_Quarter" in df.columns:
    df["Fiscal_Quarter"] = df["Fiscal_Quarter"].astype("category")

for col in ["Transaction_Amount_Local", "FX_Rate_To_USD", "Discount_Pct"]:
    if col in df.columns:
        df[col] = pd.to_numeric(df[col], errors="coerce")

critical_cols = ["Customer_ID", "Fiscal_Quarter", "Transaction_Amount_Local", "FX_Rate_To_USD"]
df = df.dropna(subset=critical_cols)
df = df.drop_duplicates()
df.to_csv(output_file, index=False, encoding="utf-8-sig")

print(f"📂 Cleaned file saved at {output_file} with shape {df.shape}")
# Out:
# 📂 Cleaned file saved at C:\Users\shenbagam\Downloads\FINALPROJECT\revenue\cleaned\customer_revenue_data_cleaned.csv with shape (54368, 5)

# %%
import pandas as pd

input_file = r"C:\Users\shenbagam\Downloads\FINALPROJECT\revenue\cleaned\customer_revenue_data_cleaned.csv"
output_file = r"C:\Users\shenbagam\Downloads\FINALPROJECT\revenue\customer_quarterly_revenue.csv"
df = pd.read_csv(input_file)
df["Revenue_USD"] = (df["Transaction_Amount_Local"] * df["FX_Rate_To_USD"]) * (1 - df["Discount_Pct"]/100)
customer_quarterly_revenue = df.groupby(["Customer_ID", "Fiscal_Quarter"])["Revenue_USD"].sum().reset_index()
customer_quarterly_revenue.to_csv(output_file, index=False, encoding="utf-8-sig")
print(f"📂 Revenue per customer per quarter saved at {output_file} with shape {customer_quarterly_revenue.shape}")
# Out:
# 📂 Revenue per customer per quarter saved at C:\Users\shenbagam\Downloads\FINALPROJECT\revenue\customer_quarterly_revenue.csv with shape (31716, 3)

# %%
import pandas as pd

input_file = r"C:\Users\shenbagam\Downloads\FINALPROJECT\revenue\customer_quarterly_revenue.csv"
output_file = r"C:\Users\shenbagam\Downloads\FINALPROJECT\revenue\customer_revenue_usd.csv"
df = pd.read_csv(input_file)
selected_df = df[["Customer_ID", "Revenue_USD"]]
selected_df.to_csv(output_file, index=False, encoding="utf-8-sig")

print(f"📂 Saved Customer_ID and Revenue_USD to {output_file} with shape {selected_df.shape}")
# Out:
# 📂 Saved Customer_ID and Revenue_USD to C:\Users\shenbagam\Downloads\FINALPROJECT\revenue\customer_revenue_usd.csv with shape (31716, 2)

# %%
import os
import pandas as pd

input_file = r"C:\Users\shenbagam\Downloads\FINALPROJECT\revenue\Customer_Revenue_USD.csv"
output_folder = r"C:\Users\shenbagam\Downloads\FINALPROJECT\revenue\cleaned"
os.makedirs(output_folder, exist_ok=True)
output_file = os.path.join(output_folder, "Customer_Revenue_USD_cleaned.csv")

df = pd.read_csv(input_file)
df.columns = df.columns.str.strip().str.replace(" ", "_")
if "Customer_ID" in df.columns:
    df["Customer_ID"] = pd.to_numeric(df["Customer_ID"], errors="coerce").astype("Int64")

if "Revenue_USD" in df.columns:
    df["Revenue_USD"] = pd.to_numeric(df["Revenue_USD"], errors="coerce")

df = df.dropna(subset=["Customer_ID", "Revenue_USD"])
df = df.drop_duplicates()
df.to_csv(output_file, index=False, encoding="utf-8-sig")

print(f"📂 Cleaned file saved at {output_file} with shape {df.shape}")
# Out:
# 📂 Cleaned file saved at C:\Users\shenbagam\Downloads\FINALPROJECT\revenue\cleaned\Customer_Revenue_USD_cleaned.csv with shape (31498, 2)

# %%
import pandas as pd

input_file = r"C:\Users\shenbagam\Downloads\FINALPROJECT\revenue\cleaned\Customer_Revenue_USD_cleaned.csv"
output_file = r"C:\Users\shenbagam\Downloads\FINALPROJECT\revenue\Customer_Total_Revenue_USD.csv"
df = pd.read_csv(input_file)
customer_total_revenue = df.groupby("Customer_ID")["Revenue_USD"].sum().reset_index()

customer_total_revenue.to_csv(output_file, index=False, encoding="utf-8-sig")

print(f"📂 Total revenue per customer saved at {output_file} with shape {customer_total_revenue.shape}")
# Out:
# 📂 Total revenue per customer saved at C:\Users\shenbagam\Downloads\FINALPROJECT\revenue\Customer_Total_Revenue_USD.csv with shape (5000, 2)

# %%
import os
import pandas as pd

input_file = r"C:\Users\shenbagam\Downloads\FINALPROJECT\revenue\Customer_Total_Revenue_USD.csv"
output_folder = r"C:\Users\shenbagam\Downloads\FINALPROJECT\revenue\cleaned"
os.makedirs(output_folder, exist_ok=True)

output_file = os.path.join(output_folder, "Customer_Total_Revenue_USD_cleaned.csv")

df = pd.read_csv(input_file)
df.columns = df.columns.str.strip().str.replace(" ", "_")

if "Customer_ID" in df.columns:
    df = df.rename(columns={"Customer_ID": "Customer_Id"})

df["Customer_Id"] = pd.to_numeric(df["Customer_Id"], errors="coerce").astype("Int64")
df["Revenue_USD"] = pd.to_numeric(df["Revenue_USD"], errors="coerce")

df = df.dropna(subset=["Customer_Id", "Revenue_USD"])
df = df.drop_duplicates()
df.to_csv(output_file, index=False, encoding="utf-8-sig")

print(f"📂 Cleaned file saved at {output_file} with shape {df.shape}")
print("Columns in cleaned file:", df.columns.tolist())
# Out:
# 📂 Cleaned file saved at C:\Users\shenbagam\Downloads\FINALPROJECT\revenue\cleaned\Customer_Total_Revenue_USD_cleaned.csv with shape (5000, 2)
# Columns in cleaned file: ['Customer_Id', 'Revenue_USD']

# %%
import pandas as pd

input_file = r"C:\Users\shenbagam\Downloads\FINALPROJECT\revenue\customer_quarterly_revenue.csv"
output_file = r"C:\Users\shenbagam\Downloads\FINALPROJECT\revenue\fiscal_revenue_usd.csv"
df = pd.read_csv(input_file)
selected_df = df[["Fiscal_Quarter", "Revenue_USD"]]
selected_df.to_csv(output_file, index=False, encoding="utf-8-sig")

print(f"📂 Saved Fiscal_Quarter and Revenue_USD to {output_file} with shape {selected_df.shape}")
# Out:
# 📂 Saved Fiscal_Quarter and Revenue_USD to C:\Users\shenbagam\Downloads\FINALPROJECT\revenue\fiscal_revenue_usd.csv with shape (31716, 2)

# %%
import pandas as pd

input_file = r"C:\Users\shenbagam\Downloads\FINALPROJECT\revenue\fiscal_revenue_usd.csv"
output_file = r"C:\Users\shenbagam\Downloads\FINALPROJECT\revenue\fiscal_revenue_usd_cleaned.csv"

df = pd.read_csv(input_file)
df = df.drop_duplicates()
df = df.dropna(subset=["Fiscal_Quarter", "Revenue_USD"])
df["Revenue_USD"] = pd.to_numeric(df["Revenue_USD"], errors="coerce")
df = df.dropna(subset=["Revenue_USD"])
df["Fiscal_Quarter"] = df["Fiscal_Quarter"].astype(str)
df.to_csv(output_file, index=False, encoding="utf-8-sig")

print(f"✅ Cleaned data saved to {output_file} with shape {df.shape}")
# Out:
# ✅ Cleaned data saved to C:\Users\shenbagam\Downloads\FINALPROJECT\revenue\fiscal_revenue_usd_cleaned.csv with shape (30648, 2)

# %%
import pandas as pd
input_file = r"C:\Users\shenbagam\Downloads\FINALPROJECT\revenue\fiscal_revenue_usd_cleaned.csv"
output_file = r"C:\Users\shenbagam\Downloads\FINALPROJECT\revenue\fiscal_revenue_usd_summary.csv"
df = pd.read_csv(input_file)

summary_df = df.groupby("Fiscal_Quarter", as_index=False)["Revenue_USD"].sum()
summary_df.to_csv(output_file, index=False, encoding="utf-8-sig")

print(f"📂 Aggregated revenue saved to {output_file} with shape {summary_df.shape}")
# Out:
# 📂 Aggregated revenue saved to C:\Users\shenbagam\Downloads\FINALPROJECT\revenue\fiscal_revenue_usd_summary.csv with shape (35, 2)

# %%
import pandas as pd
input_file = r"C:\Users\shenbagam\Downloads\FINALPROJECT\revenue\fiscal_revenue_usd_cleaned.csv"
output_file = r"C:\Users\shenbagam\Downloads\FINALPROJECT\revenue\fiscal_revenue_usd_summary_2023_2024.csv"
df = pd.read_csv(input_file)
df_filtered = df[df["Fiscal_Quarter"].str.contains("2023|2024", na=False)]
summary_df = df_filtered.groupby("Fiscal_Quarter", as_index=False)["Revenue_USD"].sum()

summary_df.to_csv(output_file, index=False, encoding="utf-8-sig")

print(f"📂 Aggregated revenue for 2023 & 2024 saved to {output_file} with shape {summary_df.shape}")
# Out:
# 📂 Aggregated revenue for 2023 & 2024 saved to C:\Users\shenbagam\Downloads\FINALPROJECT\revenue\fiscal_revenue_usd_summary_2023_2024.csv with shape (8, 2)

# %%
import pandas as pd
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import numpy as np

df = pd.read_csv(r"C:\Users\shenbagam\Downloads\FINALPROJECT\revenue\fiscal_revenue_usd_summary.csv")

df["Year"] = df["Fiscal_Quarter"].str[-4:].astype(int)
df["Quarter"] = df["Fiscal_Quarter"].str[1].astype(int)

train_df = df[df["Year"] == 2023]
test_df = df[df["Year"] == 2024]

X_train = train_df[["Year", "Quarter"]]
y_train = train_df["Revenue_USD"]
X_test = test_df[["Year", "Quarter"]]

gbr = GradientBoostingRegressor(random_state=42)
gbr.fit(X_train, y_train)
pred_gbr = gbr.predict(X_test)

xgb = XGBRegressor(random_state=42, n_estimators=200)
xgb.fit(X_train, y_train)
pred_xgb = xgb.predict(X_test)

y_pred_train = gbr.predict(X_train)
rmse = np.sqrt(mean_squared_error(y_train, y_pred_train))
mae = mean_absolute_error(y_train, y_pred_train)
r2 = r2_score(y_train, y_pred_train)

print(f"📊 Gradient Boosting Model Performance:")
print(f"RMSE: {rmse:.2f}, MAE: {mae:.2f}, R²: {r2:.2f}")

pred_df = test_df.copy()
pred_df["Predicted_Revenue_GBR"] = pred_gbr
pred_df["Predicted_Revenue_XGB"] = pred_xgb

pred_df.to_csv(r"C:\Users\shenbagam\Downloads\FINALPROJECT\revenue\predicted_revenue_2024.csv", index=False, encoding="utf-8-sig")
print("✅ Predictions saved for 2024 quarters.")
# Out:
# 📊 Gradient Boosting Model Performance:
# RMSE: 31.60, MAE: 25.40, R²: 1.00
# ✅ Predictions saved for 2024 quarters.
